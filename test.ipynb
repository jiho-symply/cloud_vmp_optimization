# %%
def first():
    print("first called")
    return 0

def last():
    print("last called")
    return 3

[t for t in range(10) if first() <= t <= last()]
# Out:
# first called
# last called
# first called
# last called
# first called
# last called
# first called
# last called
# first called
# last called
# first called
# last called
# first called
# last called
# first called
# last called
# first called
# last called
# first called
# last called
# [0, 1, 2, 3]

# %%
import yaml

with open("test.yaml", "w") as f:
    # yaml.dump({"type": [{"a": 1}, {"b": 2}]}, f, default_flow_style=None)
    yaml.dump({"type": ["A", "b"]}, f, default_flow_style=True)
